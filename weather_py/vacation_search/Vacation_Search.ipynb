# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: six in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: pygments in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: pickleshare in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: matplotlib-inline in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: backcall in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: appnope in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: decorator in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: nest-asyncio in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: fastjsonschema in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: typing-extensions in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: importlib-metadata in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: jinja2 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: nbconvert in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: bleach in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: testpath in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: beautifulsoup4 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: webencodings in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/skreefz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import gmaps

from config import g_key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0         Rikitea      PF  2022-07-01 21:12:12 -23.1203 -134.9692
# 1        1      High Level      CA  2022-07-01 21:12:12  58.5169 -117.1360
# 2        2  Ribeira Grande      PT  2022-07-01 21:12:13  38.5167  -28.7000
# 3        3            Hilo      US  2022-07-01 21:08:16  19.7297 -155.0900
# 4        4          Atuona      PF  2022-07-01 21:12:15  -9.8000 -139.0333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     71.82        74          77       14.23          light rain
# 1     69.67        26          21        5.64          few clouds
# 2     72.00        68          40        6.91    scattered clouds
# 3     84.27        72         100        6.91     overcast clouds
# 4     77.29        72           4        8.84           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip?"))
max_temp = float(input("What is the maximum temperature you would like for you trip?"))
# Out:
# What is the minimum temperature you would like for your trip?50
# What is the maximum temperature you would like for you trip?86

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# 4a. Determine if there are any empty rows.

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"]>=min_temp) & (city_data_df["Max Temp"]<=max_temp)]
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                4
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0          Rikitea      PF     71.82          light rain -23.1203 -134.9692
# 1       High Level      CA     69.67          few clouds  58.5169 -117.1360
# 2   Ribeira Grande      PT     72.00    scattered clouds  38.5167  -28.7000
# 3             Hilo      US     84.27     overcast clouds  19.7297 -155.0900
# 4           Atuona      PF     77.29           clear sky  -9.8000 -139.0333
# 5        Nantucket      US     78.91           clear sky  41.2835  -70.0995
# 6         Bengkulu      ID     72.32       broken clouds  -3.8004  102.2655
# 10      Warrington      GB     58.95          light rain  53.3925   -2.5802
# 12          Keuruu      FI     73.58     overcast clouds  62.2667   24.7000
# 13      Nikolskoye      RU     67.91     overcast clouds  59.7035   30.7861
#
#    Hotel Name
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 10
# 12
# 13

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0          Rikitea      PF     71.82          light rain -23.1203 -134.9692
# 1       High Level      CA     69.67          few clouds  58.5169 -117.1360
# 2   Ribeira Grande      PT     72.00    scattered clouds  38.5167  -28.7000
# 3             Hilo      US     84.27     overcast clouds  19.7297 -155.0900
# 4           Atuona      PF     77.29           clear sky  -9.8000 -139.0333
# 5        Nantucket      US     78.91           clear sky  41.2835  -70.0995
# 6         Bengkulu      ID     72.32       broken clouds  -3.8004  102.2655
# 10      Warrington      GB     58.95          light rain  53.3925   -2.5802
# 12          Keuruu      FI     73.58     overcast clouds  62.2667   24.7000
# 13      Nikolskoye      RU     67.91     overcast clouds  59.7035   30.7861
#
#    Hotel Name
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 10
# 12
# 13

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
# 6b. Iterate through the hotel DataFrame.
    # 6c. Get latitude and longitude from DataFrame    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    # 6e. Make request and retrieve the JSON data from the search. 
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.

params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    hotels = requests.get(base_url, params=params).json()
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except:
        continue

# %%
# 7. Drop the rows where there is no Hotel Name.

clean_hotel_df = hotel_df.dropna()
clean_hotel_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Max Temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %%
# 8a. Create the output File (CSV)
# 8b. Export the City_Data into a csv

output_data_file = "WeatherPy_vacation.csv"
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
# 11b. Display the figure

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
