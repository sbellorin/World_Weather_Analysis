# %%
from config import weather_api_key, g_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
import time
from scipy.stats import linregress

# %%
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

coordinates = zip(lats, lngs)
cities = []


for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    
    city_url = url + weather_api_key + "&q=" + city.replace(" ", "+")
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        
        city_data.append({
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date
                        })
        
    except KeyError:
        print("City not found. Skipping...")
        continue
        
    print(f"Processing record count {record_count} of set {set_count} | {city}")
    record_count += 1
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record count 1 of set 1 | rikitea
# Processing record count 2 of set 1 | high level
# Processing record count 3 of set 1 | ribeira grande
# City not found. Skipping...
# Processing record count 4 of set 1 | hilo
# Processing record count 5 of set 1 | atuona
# Processing record count 6 of set 1 | nantucket
# City not found. Skipping...
# Processing record count 7 of set 1 | bengkulu
# City not found. Skipping...
# Processing record count 8 of set 1 | punta arenas
# Processing record count 9 of set 1 | upernavik
# Processing record count 10 of set 1 | ushuaia
# Processing record count 11 of set 1 | warrington
# Processing record count 12 of set 1 | albany
# City not found. Skipping...
# Processing record count 13 of set 1 | keuruu
# Processing record count 14 of set 1 | nikolskoye
# Processing record count 15 of set 1 | pangody
# Processing record count 16 of set 1 | tuatapere
# Processing record count 17 of set 1 | tottori
# City not found. Skipping...
# Processing record count 18 of set 1 | saint-philippe
# Processing record count 19 of set 1 | yellowknife
# Processing record count 20 of set 1 | ardesen
# Processing record count 21 of set 1 | kapaa
# Processing record count 22 of set 1 | dalby
# Processing record count 23 of set 1 | lac-megantic
# Processing record count 24 of set 1 | bethel
# Processing record count 25 of set 1 | atar
# Processing record count 26 of set 1 | anju
# Processing record count 27 of set 1 | duluth
# Processing record count 28 of set 1 | busselton
# Processing record count 29 of set 1 | lusaka
# Processing record count 30 of set 1 | hithadhoo
# City not found. Skipping...
# Processing record count 31 of set 1 | tasiilaq
# Processing record count 32 of set 1 | puerto ayora
# Processing record count 33 of set 1 | aykhal
# Processing record count 34 of set 1 | pacifica
# Processing record count 35 of set 1 | mataura
# City not found. Skipping...
# Processing record count 36 of set 1 | margate
# Processing record count 37 of set 1 | altamira
# Processing record count 38 of set 1 | jamestown
# Processing record count 39 of set 1 | bredasdorp
# Processing record count 40 of set 1 | yar-sale
# Processing record count 41 of set 1 | banda aceh
# Processing record count 42 of set 1 | sawankhalok
# City not found. Skipping...
# Processing record count 1 of set 2 | mount isa
# Processing record count 2 of set 2 | poopo
# Processing record count 3 of set 2 | port lincoln
# Processing record count 4 of set 2 | new norfolk
# City not found. Skipping...
# Processing record count 5 of set 2 | vaini
# City not found. Skipping...
# Processing record count 6 of set 2 | niort
# Processing record count 7 of set 2 | charters towers
# Processing record count 8 of set 2 | zhigansk
# Processing record count 9 of set 2 | takoradi
# Processing record count 10 of set 2 | hobart
# Processing record count 11 of set 2 | hauterive
# Processing record count 12 of set 2 | waipawa
# Processing record count 13 of set 2 | grand gaube
# Processing record count 14 of set 2 | yabrud
# Processing record count 15 of set 2 | namatanai
# Processing record count 16 of set 2 | koppal
# Processing record count 17 of set 2 | chanika
# Processing record count 18 of set 2 | road town
# Processing record count 19 of set 2 | saskylakh
# Processing record count 20 of set 2 | ponta do sol
# Processing record count 21 of set 2 | bambous virieux
# Processing record count 22 of set 2 | castro
# Processing record count 23 of set 2 | kommunar
# Processing record count 24 of set 2 | cidreira
# Processing record count 25 of set 2 | bluff
# Processing record count 26 of set 2 | thunder bay
# Processing record count 27 of set 2 | east london
# Processing record count 28 of set 2 | dikson
# Processing record count 29 of set 2 | buchanan
# Processing record count 30 of set 2 | mahebourg
# Processing record count 31 of set 2 | san patricio
# Processing record count 32 of set 2 | mahuva
# City not found. Skipping...
# Processing record count 33 of set 2 | hermanus
# Processing record count 34 of set 2 | marienburg
# Processing record count 35 of set 2 | verkhnevilyuysk
# Processing record count 36 of set 2 | beringovskiy
# Processing record count 37 of set 2 | samarai
# Processing record count 38 of set 2 | lasa
# Processing record count 39 of set 2 | tautira
# City not found. Skipping...
# Processing record count 40 of set 2 | den helder
# Processing record count 41 of set 2 | kununurra
# Processing record count 42 of set 2 | tessalit
# Processing record count 43 of set 2 | buala
# Processing record count 44 of set 2 | padang
# Processing record count 45 of set 2 | coquimbo
# Processing record count 46 of set 2 | srednekolymsk
# Processing record count 1 of set 3 | cape town
# Processing record count 2 of set 3 | la ronge
# Processing record count 3 of set 3 | port alfred
# Processing record count 4 of set 3 | praia
# Processing record count 5 of set 3 | souillac
# Processing record count 6 of set 3 | avarua
# Processing record count 7 of set 3 | butaritari
# Processing record count 8 of set 3 | matay
# Processing record count 9 of set 3 | guerrero negro
# Processing record count 10 of set 3 | acoyapa
# Processing record count 11 of set 3 | longyearbyen
# Processing record count 12 of set 3 | vestmannaeyjar
# Processing record count 13 of set 3 | talnakh
# Processing record count 14 of set 3 | olavarria
# Processing record count 15 of set 3 | bose
# Processing record count 16 of set 3 | carnarvon
# Processing record count 17 of set 3 | murgab
# Processing record count 18 of set 3 | lahan
# Processing record count 19 of set 3 | anloga
# Processing record count 20 of set 3 | puerto carreno
# Processing record count 21 of set 3 | kargat
# Processing record count 22 of set 3 | khatanga
# Processing record count 23 of set 3 | codrington
# Processing record count 24 of set 3 | amapa
# Processing record count 25 of set 3 | kondinskoye
# Processing record count 26 of set 3 | qaanaaq
# City not found. Skipping...
# Processing record count 27 of set 3 | yuncheng
# Processing record count 28 of set 3 | ancud
# City not found. Skipping...
# Processing record count 29 of set 3 | saint george
# Processing record count 30 of set 3 | urengoy
# Processing record count 31 of set 3 | tuktoyaktuk
# Processing record count 32 of set 3 | dingle
# Processing record count 33 of set 3 | pisco
# Processing record count 34 of set 3 | sovetskiy
# Processing record count 35 of set 3 | bentiu
# Processing record count 36 of set 3 | touros
# Processing record count 37 of set 3 | pyapon
# Processing record count 38 of set 3 | vardo
# Processing record count 39 of set 3 | hun
# Processing record count 40 of set 3 | newton
# Processing record count 41 of set 3 | las choapas
# Processing record count 42 of set 3 | airai
# Processing record count 43 of set 3 | cabo rojo
# Processing record count 44 of set 3 | sisimiut
# Processing record count 45 of set 3 | provideniya
# Processing record count 46 of set 3 | almeria
# Processing record count 47 of set 3 | port shepstone
# Processing record count 48 of set 3 | lebu
# City not found. Skipping...
# Processing record count 1 of set 4 | san cristobal
# Processing record count 2 of set 4 | severo-kurilsk
# Processing record count 3 of set 4 | chiredzi
# Processing record count 4 of set 4 | mar del plata
# Processing record count 5 of set 4 | lisieux
# Processing record count 6 of set 4 | kutum
# Processing record count 7 of set 4 | kysyl-syr
# Processing record count 8 of set 4 | ca mau
# Processing record count 9 of set 4 | leningradskiy
# Processing record count 10 of set 4 | luocheng
# Processing record count 11 of set 4 | norman wells
# Processing record count 12 of set 4 | xuddur
# Processing record count 13 of set 4 | urubicha
# Processing record count 14 of set 4 | amga
# Processing record count 15 of set 4 | kodar
# City not found. Skipping...
# Processing record count 16 of set 4 | iqaluit
# Processing record count 17 of set 4 | nome
# Processing record count 18 of set 4 | barrow
# City not found. Skipping...
# Processing record count 19 of set 4 | sorland
# Processing record count 20 of set 4 | hami
# Processing record count 21 of set 4 | marquette
# City not found. Skipping...
# Processing record count 22 of set 4 | villa maria
# Processing record count 23 of set 4 | faanui
# City not found. Skipping...
# Processing record count 24 of set 4 | lagoa
# Processing record count 25 of set 4 | pitimbu
# Processing record count 26 of set 4 | bartlesville
# Processing record count 27 of set 4 | tiksi
# Processing record count 28 of set 4 | salalah
# Processing record count 29 of set 4 | nelson bay
# Processing record count 30 of set 4 | babstovo
# Processing record count 31 of set 4 | broken hill
# City not found. Skipping...
# Processing record count 32 of set 4 | mogadishu
# Processing record count 33 of set 4 | pontes e lacerda
# Processing record count 34 of set 4 | pirovskoye
# Processing record count 35 of set 4 | nosy varika
# Processing record count 36 of set 4 | puerto narino
# Processing record count 37 of set 4 | amahai
# Processing record count 38 of set 4 | roald
# Processing record count 39 of set 4 | millet
# Processing record count 40 of set 4 | tromso
# Processing record count 41 of set 4 | kargasok
# Processing record count 42 of set 4 | sola
# Processing record count 43 of set 4 | port blair
# Processing record count 44 of set 4 | berbera
# Processing record count 1 of set 5 | fort nelson
# Processing record count 2 of set 5 | sobolevo
# Processing record count 3 of set 5 | roma
# Processing record count 4 of set 5 | kodiak
# Processing record count 5 of set 5 | dharchula
# Processing record count 6 of set 5 | miracema
# Processing record count 7 of set 5 | port hedland
# Processing record count 8 of set 5 | majene
# Processing record count 9 of set 5 | simao
# Processing record count 10 of set 5 | narsaq
# Processing record count 11 of set 5 | arklow
# Processing record count 12 of set 5 | sandwick
# Processing record count 13 of set 5 | veracruz
# Processing record count 14 of set 5 | caborca
# City not found. Skipping...
# Processing record count 15 of set 5 | vila franca do campo
# Processing record count 16 of set 5 | sorong
# Processing record count 17 of set 5 | kavieng
# Processing record count 18 of set 5 | fortuna foothills
# Processing record count 19 of set 5 | vila velha
# Processing record count 20 of set 5 | cheney
# Processing record count 21 of set 5 | kushiro
# Processing record count 22 of set 5 | atasu
# City not found. Skipping...
# Processing record count 23 of set 5 | port hardy
# Processing record count 24 of set 5 | kruisfontein
# Processing record count 25 of set 5 | pangai
# Processing record count 26 of set 5 | palmas
# Processing record count 27 of set 5 | bilibino
# Processing record count 28 of set 5 | olafsvik
# Processing record count 29 of set 5 | lerwick
# Processing record count 30 of set 5 | vinh
# Processing record count 31 of set 5 | kuching
# Processing record count 32 of set 5 | arraial do cabo
# Processing record count 33 of set 5 | cherskiy
# Processing record count 34 of set 5 | asosa
# Processing record count 35 of set 5 | carroll
# Processing record count 36 of set 5 | penzance
# Processing record count 37 of set 5 | ahuimanu
# Processing record count 38 of set 5 | tateyama
# Processing record count 39 of set 5 | miri
# Processing record count 40 of set 5 | fukue
# Processing record count 41 of set 5 | kalabo
# Processing record count 42 of set 5 | fortuna
# Processing record count 43 of set 5 | ilulissat
# Processing record count 44 of set 5 | point pedro
# Processing record count 45 of set 5 | belaya gora
# Processing record count 46 of set 5 | benguela
# Processing record count 47 of set 5 | baykit
# Processing record count 48 of set 5 | strausberg
# Processing record count 1 of set 6 | acarau
# Processing record count 2 of set 6 | yuancheng
# Processing record count 3 of set 6 | anadyr
# City not found. Skipping...
# Processing record count 4 of set 6 | araouane
# Processing record count 5 of set 6 | yatou
# Processing record count 6 of set 6 | lukaya
# Processing record count 7 of set 6 | shunyi
# Processing record count 8 of set 6 | bowen
# Processing record count 9 of set 6 | pouembout
# Processing record count 10 of set 6 | paamiut
# Processing record count 11 of set 6 | lorengau
# Processing record count 12 of set 6 | taywarah
# Processing record count 13 of set 6 | hasaki
# Processing record count 14 of set 6 | dubbo
# Processing record count 15 of set 6 | laizhou
# Processing record count 16 of set 6 | kabwe
# Processing record count 17 of set 6 | alta gracia
# Processing record count 18 of set 6 | yarmouth
# Processing record count 19 of set 6 | port elizabeth
# Processing record count 20 of set 6 | tabuk
# Processing record count 21 of set 6 | hirara
# Processing record count 22 of set 6 | linguere
# Processing record count 23 of set 6 | san quintin
# Processing record count 24 of set 6 | leh
# Processing record count 25 of set 6 | torbay
# Processing record count 26 of set 6 | matara
# City not found. Skipping...
# Processing record count 27 of set 6 | sioux lookout
# Processing record count 28 of set 6 | jadu
# Processing record count 29 of set 6 | killybegs
# Processing record count 30 of set 6 | srivardhan
# Processing record count 31 of set 6 | kupang
# Processing record count 32 of set 6 | esperance
# Processing record count 33 of set 6 | cairns
# Processing record count 34 of set 6 | stropkov
# Processing record count 35 of set 6 | half moon bay
# Processing record count 36 of set 6 | georgetown
# Processing record count 37 of set 6 | bayamo
# Processing record count 38 of set 6 | praia da vitoria
# Processing record count 39 of set 6 | huilong
# Processing record count 40 of set 6 | alta floresta
# Processing record count 41 of set 6 | ukiah
# Processing record count 42 of set 6 | dabat
# Processing record count 43 of set 6 | kaitangata
# Processing record count 44 of set 6 | osorno
# Processing record count 45 of set 6 | tulum
# City not found. Skipping...
# Processing record count 46 of set 6 | namibe
# Processing record count 47 of set 6 | gizo
# Processing record count 1 of set 7 | barahona
# Processing record count 2 of set 7 | gigmoto
# Processing record count 3 of set 7 | la rioja
# Processing record count 4 of set 7 | dalbandin
# City not found. Skipping...
# Processing record count 5 of set 7 | chemax
# Processing record count 6 of set 7 | howard springs
# City not found. Skipping...
# Processing record count 7 of set 7 | olinda
# Processing record count 8 of set 7 | nanortalik
# Processing record count 9 of set 7 | geraldton
# Processing record count 10 of set 7 | sechura
# Processing record count 11 of set 7 | los llanos de aridane
# Processing record count 12 of set 7 | tefe
# Processing record count 13 of set 7 | necochea
# Processing record count 14 of set 7 | orange cove
# Processing record count 15 of set 7 | thompson
# Processing record count 16 of set 7 | yulara
# Processing record count 17 of set 7 | saldanha
# Processing record count 18 of set 7 | talcahuano
# Processing record count 19 of set 7 | paris
# Processing record count 20 of set 7 | mosquera
# Processing record count 21 of set 7 | darhan
# Processing record count 22 of set 7 | santa ines
# Processing record count 23 of set 7 | qaqortoq
# Processing record count 24 of set 7 | piripiri
# City not found. Skipping...
# Processing record count 25 of set 7 | alofi
# City not found. Skipping...
# Processing record count 26 of set 7 | lukulu
# Processing record count 27 of set 7 | lufilufi
# Processing record count 28 of set 7 | yangambi
# Processing record count 29 of set 7 | lazaro cardenas
# Processing record count 30 of set 7 | sinop
# Processing record count 31 of set 7 | shache
# Processing record count 32 of set 7 | sabzevar
# Processing record count 33 of set 7 | hovd
# Processing record count 34 of set 7 | saint-pierre
# Processing record count 35 of set 7 | kinablangan
# City not found. Skipping...
# Processing record count 36 of set 7 | semirom
# Processing record count 37 of set 7 | sao filipe
# Processing record count 38 of set 7 | sitka
# Processing record count 39 of set 7 | port macquarie
# Processing record count 40 of set 7 | vanimo
# Processing record count 41 of set 7 | anupgarh
# Processing record count 42 of set 7 | camaguey
# Processing record count 43 of set 7 | christchurch
# Processing record count 44 of set 7 | belur
# Processing record count 45 of set 7 | shenjiamen
# Processing record count 1 of set 8 | dao
# Processing record count 2 of set 8 | hamilton
# Processing record count 3 of set 8 | hambantota
# Processing record count 4 of set 8 | bathsheba
# City not found. Skipping...
# Processing record count 5 of set 8 | fairbanks
# Processing record count 6 of set 8 | inhambane
# Processing record count 7 of set 8 | cabo san lucas
# Processing record count 8 of set 8 | oktyabrskiy
# Processing record count 9 of set 8 | honiara
# Processing record count 10 of set 8 | kaeo
# Processing record count 11 of set 8 | coihaique
# Processing record count 12 of set 8 | grindavik
# Processing record count 13 of set 8 | aklavik
# Processing record count 14 of set 8 | escanaba
# Processing record count 15 of set 8 | ponta delgada
# Processing record count 16 of set 8 | malakal
# Processing record count 17 of set 8 | rawson
# Processing record count 18 of set 8 | sinnamary
# Processing record count 19 of set 8 | iwanai
# Processing record count 20 of set 8 | nokaneng
# Processing record count 21 of set 8 | klaksvik
# Processing record count 22 of set 8 | korla
# Processing record count 23 of set 8 | sumbe
# Processing record count 24 of set 8 | iranshahr
# Processing record count 25 of set 8 | mafinga
# Processing record count 26 of set 8 | alto araguaia
# City not found. Skipping...
# Processing record count 27 of set 8 | aanekoski
# Processing record count 28 of set 8 | pointe michel
# Processing record count 29 of set 8 | soyo
# Processing record count 30 of set 8 | unai
# Processing record count 31 of set 8 | fria
# Processing record count 32 of set 8 | pak phanang
# Processing record count 33 of set 8 | ponazyrevo
# Processing record count 34 of set 8 | egvekinot
# Processing record count 35 of set 8 | saint-marc
# City not found. Skipping...
# Processing record count 36 of set 8 | ahipara
# Processing record count 37 of set 8 | konce
# Processing record count 38 of set 8 | igrim
# Processing record count 39 of set 8 | ust-tarka
# Processing record count 40 of set 8 | chapais
# Processing record count 41 of set 8 | havre-saint-pierre
# Processing record count 42 of set 8 | borovoy
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 43 of set 8 | orasac
# Processing record count 44 of set 8 | bauska
# Processing record count 45 of set 8 | key west
# Processing record count 1 of set 9 | laguna
# Processing record count 2 of set 9 | lavrentiya
# Processing record count 3 of set 9 | okato
# Processing record count 4 of set 9 | college
# Processing record count 5 of set 9 | havoysund
# Processing record count 6 of set 9 | hirtshals
# Processing record count 7 of set 9 | yangjiang
# Processing record count 8 of set 9 | pevek
# Processing record count 9 of set 9 | komsomolskiy
# Processing record count 10 of set 9 | araceli
# Processing record count 11 of set 9 | damoh
# Processing record count 12 of set 9 | itarema
# City not found. Skipping...
# Processing record count 13 of set 9 | pavelets
# Processing record count 14 of set 9 | adzope
# Processing record count 15 of set 9 | hemsedal
# Processing record count 16 of set 9 | kirakira
# Processing record count 17 of set 9 | camacha
# Processing record count 18 of set 9 | prince rupert
# Processing record count 19 of set 9 | goldap
# Processing record count 20 of set 9 | hashtrud
# Processing record count 21 of set 9 | bima
# Processing record count 22 of set 9 | tarakan
# Processing record count 23 of set 9 | carutapera
# Processing record count 24 of set 9 | rabo de peixe
# Processing record count 25 of set 9 | awjilah
# Processing record count 26 of set 9 | maragogi
# Processing record count 27 of set 9 | hobyo
# City not found. Skipping...
# Processing record count 28 of set 9 | warrnambool
# Processing record count 29 of set 9 | victoria
# Processing record count 30 of set 9 | vila
# Processing record count 31 of set 9 | shirokiy
# Processing record count 32 of set 9 | tahe
# Processing record count 33 of set 9 | yichang
# Processing record count 34 of set 9 | santa cruz
# Processing record count 35 of set 9 | sharjah
# Processing record count 36 of set 9 | chokurdakh
# Processing record count 37 of set 9 | nouakchott
# Processing record count 38 of set 9 | sistranda
# Processing record count 39 of set 9 | macusani
# Processing record count 40 of set 9 | mount gambier
# Processing record count 41 of set 9 | san juan
# Processing record count 42 of set 9 | tupelo
# Processing record count 43 of set 9 | angoche
# Processing record count 44 of set 9 | haines junction
# Processing record count 45 of set 9 | kushima
# Processing record count 46 of set 9 | caravelas
# Processing record count 47 of set 9 | altoona
# Processing record count 48 of set 9 | salaga
# Processing record count 1 of set 10 | zhuanghe
# Processing record count 2 of set 10 | duobao
# Processing record count 3 of set 10 | beloha
# Processing record count 4 of set 10 | tabasalu
# Processing record count 5 of set 10 | boyolangu
# Processing record count 6 of set 10 | meiganga
# City not found. Skipping...
# Processing record count 7 of set 10 | vostok
# Processing record count 8 of set 10 | chicama
# Processing record count 9 of set 10 | tecpan
# Processing record count 10 of set 10 | vysokogornyy
# Processing record count 11 of set 10 | flinders
# City not found. Skipping...
# Processing record count 12 of set 10 | ayagoz
# Processing record count 13 of set 10 | xochihuehuetlan
# Processing record count 14 of set 10 | labuan
# Processing record count 15 of set 10 | northam
# Processing record count 16 of set 10 | warangal
# Processing record count 17 of set 10 | katsuura
# Processing record count 18 of set 10 | carauari
# Processing record count 19 of set 10 | volkhov
# Processing record count 20 of set 10 | port moresby
# Processing record count 21 of set 10 | toul
# Processing record count 22 of set 10 | aswan
# Processing record count 23 of set 10 | bairiki
# City not found. Skipping...
# Processing record count 24 of set 10 | saint-francois
# Processing record count 25 of set 10 | yaan
# Processing record count 26 of set 10 | aban
# Processing record count 27 of set 10 | khovu-aksy
# Processing record count 28 of set 10 | kaa-khem
# Processing record count 29 of set 10 | cayenne
# Processing record count 30 of set 10 | pelym
# Processing record count 31 of set 10 | olesno
# Processing record count 32 of set 10 | tolmezzo
# Processing record count 33 of set 10 | monte alegre
# Processing record count 34 of set 10 | juneau
# Processing record count 35 of set 10 | launceston
# Processing record count 36 of set 10 | filadelfia
# Processing record count 37 of set 10 | jiblah
# Processing record count 38 of set 10 | dois corregos
# City not found. Skipping...
# Processing record count 39 of set 10 | dhankuta
# Processing record count 40 of set 10 | pavilosta
# Processing record count 41 of set 10 | opuwo
# City not found. Skipping...
# Processing record count 42 of set 10 | chuy
# Processing record count 43 of set 10 | russell
# City not found. Skipping...
# Processing record count 44 of set 10 | preston
# Processing record count 1 of set 11 | vizinga
# Processing record count 2 of set 11 | collie
# Processing record count 3 of set 11 | yuxia
# City not found. Skipping...
# Processing record count 4 of set 11 | isangel
# Processing record count 5 of set 11 | plavinas
# Processing record count 6 of set 11 | diego de almagro
# Processing record count 7 of set 11 | champerico
# Processing record count 8 of set 11 | hadejia
# Processing record count 9 of set 11 | betioky
# Processing record count 10 of set 11 | smirnykh
# Processing record count 11 of set 11 | parry sound
# Processing record count 12 of set 11 | tekeli
# Processing record count 13 of set 11 | lompoc
# Processing record count 14 of set 11 | port hawkesbury
# Processing record count 15 of set 11 | krasnoselkup
# Processing record count 16 of set 11 | te anau
# Processing record count 17 of set 11 | xixiang
# Processing record count 18 of set 11 | bulri
# Processing record count 19 of set 11 | mariel
# Processing record count 20 of set 11 | sao joao da barra
# Processing record count 21 of set 11 | naze
# Processing record count 22 of set 11 | ngunguru
# Processing record count 23 of set 11 | surt
# Processing record count 24 of set 11 | alice springs
# Processing record count 25 of set 11 | mackay
# Processing record count 26 of set 11 | clyde river
# Processing record count 27 of set 11 | porto empedocle
# Processing record count 28 of set 11 | kahului
# Processing record count 29 of set 11 | lakhdenpokhya
# Processing record count 30 of set 11 | abha
# Processing record count 31 of set 11 | port arthur
# Processing record count 32 of set 11 | shrewsbury
# Processing record count 33 of set 11 | zhenhai
# Processing record count 34 of set 11 | san felipe
# Processing record count 35 of set 11 | oyem
# Processing record count 36 of set 11 | phan thiet
# Processing record count 37 of set 11 | khor
# Processing record count 38 of set 11 | front royal
# Processing record count 39 of set 11 | leshan
# Processing record count 40 of set 11 | lumeje
# Processing record count 41 of set 11 | polunochnoye
# Processing record count 42 of set 11 | harper
# Processing record count 43 of set 11 | huambo
# City not found. Skipping...
# Processing record count 44 of set 11 | ambilobe
# Processing record count 45 of set 11 | kieta
# City not found. Skipping...
# Processing record count 46 of set 11 | batemans bay
# Processing record count 47 of set 11 | canto do buriti
# Processing record count 1 of set 12 | dakar
# Processing record count 2 of set 12 | sakakah
# Processing record count 3 of set 12 | puerto escondido
# Processing record count 4 of set 12 | imperia
# Processing record count 5 of set 12 | kidal
# City not found. Skipping...
# Processing record count 6 of set 12 | staritsa
# Processing record count 7 of set 12 | palmer
# Processing record count 8 of set 12 | cabedelo
# Processing record count 9 of set 12 | mashivka
# Processing record count 10 of set 12 | zboriste
# Processing record count 11 of set 12 | brae
# Processing record count 12 of set 12 | kotido
# Processing record count 13 of set 12 | sydney
# Processing record count 14 of set 12 | robertsport
# Processing record count 15 of set 12 | dudinka
# Processing record count 16 of set 12 | torbat-e jam
# Processing record count 17 of set 12 | bulgan
# Processing record count 18 of set 12 | beyneu
# Processing record count 19 of set 12 | hofn
# Processing record count 20 of set 12 | dunedin
# Processing record count 21 of set 12 | khunzakh
# Processing record count 22 of set 12 | luderitz
# City not found. Skipping...
# Processing record count 23 of set 12 | copiapo
# Processing record count 24 of set 12 | formosa
# Processing record count 25 of set 12 | taksimo
# Processing record count 26 of set 12 | svobodnyy
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 27 of set 12 | shingu
# City not found. Skipping...
# Processing record count 28 of set 12 | bani walid
# Processing record count 29 of set 12 | ocos
# Processing record count 30 of set 12 | petropavlovsk-kamchatskiy
# Processing record count 31 of set 12 | corowa
# Processing record count 32 of set 12 | husavik
# Processing record count 33 of set 12 | minab
# Processing record count 34 of set 12 | martapura
# City not found. Skipping...
# Processing record count 35 of set 12 | balykshi
# Processing record count 36 of set 12 | perdoes
# Processing record count 37 of set 12 | saint-joseph
# Processing record count 38 of set 12 | faenza
# Processing record count 39 of set 12 | acapulco
# Processing record count 40 of set 12 | avesta
# Processing record count 41 of set 12 | alor setar
# Processing record count 42 of set 12 | koumac
# Processing record count 43 of set 12 | cermik
# Processing record count 44 of set 12 | kuwana
# Processing record count 1 of set 13 | vao
# Processing record count 2 of set 13 | shakawe
# Processing record count 3 of set 13 | burdur
# Processing record count 4 of set 13 | mantua
# Processing record count 5 of set 13 | bonfim
# Processing record count 6 of set 13 | monserrato
# Processing record count 7 of set 13 | kailua
# Processing record count 8 of set 13 | hamina
# Processing record count 9 of set 13 | nurota
# Processing record count 10 of set 13 | leeton
# Processing record count 11 of set 13 | mizan teferi
# Processing record count 12 of set 13 | reconquista
# Processing record count 13 of set 13 | kashi
# Processing record count 14 of set 13 | kiruna
# Processing record count 15 of set 13 | onega
# Processing record count 16 of set 13 | mabaruma
# Processing record count 17 of set 13 | halifax
# Processing record count 18 of set 13 | samdari
# Processing record count 19 of set 13 | phangnga
# Processing record count 20 of set 13 | melito di porto salvo
# Processing record count 21 of set 13 | huntington
# Processing record count 22 of set 13 | ishinomaki
# Processing record count 23 of set 13 | nha trang
# Processing record count 24 of set 13 | kichera
# Processing record count 25 of set 13 | grand-lahou
# Processing record count 26 of set 13 | labuhan
# Processing record count 27 of set 13 | sokolo
# Processing record count 28 of set 13 | zhigalovo
# Processing record count 29 of set 13 | hay river
# Processing record count 30 of set 13 | nalut
# Processing record count 31 of set 13 | guaymas
# Processing record count 32 of set 13 | qasigiannguit
# Processing record count 33 of set 13 | santa cruz cabralia
# Processing record count 34 of set 13 | west wendover
# Processing record count 35 of set 13 | tilichiki
# Processing record count 36 of set 13 | bestobe
# Processing record count 37 of set 13 | paramirim
# Processing record count 38 of set 13 | impfondo
# Processing record count 39 of set 13 | bacolod
# Processing record count 40 of set 13 | manicore
# Processing record count 41 of set 13 | betare oya
# Processing record count 42 of set 13 | kisangani
# Processing record count 43 of set 13 | naron
# Processing record count 44 of set 13 | kandrian
# Processing record count 45 of set 13 | meulaboh
# Processing record count 46 of set 13 | rupert
# Processing record count 47 of set 13 | nabire
# Processing record count 48 of set 13 | tual
# Processing record count 49 of set 13 | aguas formosas
# Processing record count 50 of set 13 | vanavara
# Processing record count 1 of set 14 | sindhnur
# Processing record count 2 of set 14 | shaoguan
# Processing record count 3 of set 14 | marzuq
# Processing record count 4 of set 14 | ballina
# Processing record count 5 of set 14 | henties bay
# Processing record count 6 of set 14 | abu dhabi
# Processing record count 7 of set 14 | asfi
# Processing record count 8 of set 14 | ituango
# Processing record count 9 of set 14 | whitehorse
# Processing record count 10 of set 14 | quatre cocos
# City not found. Skipping...
# Processing record count 11 of set 14 | sao jose da coroa grande
# Processing record count 12 of set 14 | rio gallegos
# Processing record count 13 of set 14 | indianola
# Processing record count 14 of set 14 | bhuj
# Processing record count 15 of set 14 | bonavista
# Processing record count 16 of set 14 | novokizhinginsk
# City not found. Skipping...
# Processing record count 17 of set 14 | tazovskiy
# Processing record count 18 of set 14 | ushirombo
# Processing record count 19 of set 14 | albac
# Processing record count 20 of set 14 | assiniboia
# Processing record count 21 of set 14 | astaneh-ye ashrafiyeh
# Processing record count 22 of set 14 | seoul
# Processing record count 23 of set 14 | drayton valley
# Processing record count 24 of set 14 | katobu
# City not found. Skipping...
# Processing record count 25 of set 14 | mehriz
# Processing record count 26 of set 14 | standerton
# City not found. Skipping...
# Processing record count 27 of set 14 | gornopravdinsk
# Processing record count 28 of set 14 | cururupu
# City not found. Skipping...
# Processing record count 29 of set 14 | noumea
# Processing record count 30 of set 14 | la romana
# Processing record count 31 of set 14 | kawambwa
# Processing record count 32 of set 14 | radhanpur
# Processing record count 33 of set 14 | hokitika
# Processing record count 34 of set 14 | kindu
# Processing record count 35 of set 14 | oriximina
# Processing record count 36 of set 14 | omboue
# Processing record count 37 of set 14 | goderich
# Processing record count 38 of set 14 | biltine
# Processing record count 39 of set 14 | winslow
# Processing record count 40 of set 14 | bud
# Processing record count 41 of set 14 | la tuque
# Processing record count 42 of set 14 | bagan
# Processing record count 43 of set 14 | kavaratti
# Processing record count 44 of set 14 | krasnyy chikoy
# City not found. Skipping...
# Processing record count 1 of set 15 | monterey
# City not found. Skipping...
# Processing record count 2 of set 15 | eyl
# Processing record count 3 of set 15 | oussouye
# Processing record count 4 of set 15 | kamuli
# Processing record count 5 of set 15 | genhe
# Processing record count 6 of set 15 | constitucion
# Processing record count 7 of set 15 | illela
# Processing record count 8 of set 15 | kathu
# Processing record count 9 of set 15 | nisia floresta
# Processing record count 10 of set 15 | sur
# Processing record count 11 of set 15 | tezu
# Processing record count 12 of set 15 | tambopata
# City not found. Skipping...
# Processing record count 13 of set 15 | athens
# Processing record count 14 of set 15 | siderno
# Processing record count 15 of set 15 | ciudad bolivar
# Processing record count 16 of set 15 | yelkhovka
# Processing record count 17 of set 15 | shimoda
# Processing record count 18 of set 15 | arlit
# Processing record count 19 of set 15 | pingliang
# Processing record count 20 of set 15 | kuandian
# Processing record count 21 of set 15 | funadhoo
# Processing record count 22 of set 15 | sinjar
# Processing record count 23 of set 15 | salta
# Processing record count 24 of set 15 | blairmore
# Processing record count 25 of set 15 | adelaide
# Processing record count 26 of set 15 | khromtau
# Processing record count 27 of set 15 | svetlogorsk
# Processing record count 28 of set 15 | homer
# Processing record count 29 of set 15 | emerald
# Processing record count 30 of set 15 | mangai
# Processing record count 31 of set 15 | etropole
# Processing record count 32 of set 15 | asyut
# Processing record count 33 of set 15 | biloela
# Processing record count 34 of set 15 | sloboda
# Processing record count 35 of set 15 | esna
# Processing record count 36 of set 15 | portland
# Processing record count 37 of set 15 | chemainus
# Processing record count 38 of set 15 | sawtell
# City not found. Skipping...
# Processing record count 39 of set 15 | nadym
# Processing record count 40 of set 15 | banjar
# Processing record count 41 of set 15 | boende
# City not found. Skipping...
# Processing record count 42 of set 15 | sao joao dos patos
# Processing record count 43 of set 15 | maniitsoq
# Processing record count 44 of set 15 | turochak
# Processing record count 45 of set 15 | lagos
# Processing record count 46 of set 15 | walvis bay
# Processing record count 1 of set 16 | erzin
# Processing record count 2 of set 16 | zaozerne
# Processing record count 3 of set 16 | the valley
# Processing record count 4 of set 16 | vestmanna
# Processing record count 5 of set 16 | areka
# Processing record count 6 of set 16 | dibulla
# Processing record count 7 of set 16 | male
# Processing record count 8 of set 16 | opotiki
# Processing record count 9 of set 16 | kalmunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
